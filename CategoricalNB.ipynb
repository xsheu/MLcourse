# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load real Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Select meaningful categorical columns
X = df[['Pclass', 'Sex', 'Embarked']].astype(str)
y = df['Survived']

# Handle missing data
X = X.fillna('missing')

# Encode string categories to numeric
encoder = OrdinalEncoder()
X_encoded = encoder.fit_transform(X)

# Split train/test
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.25, random_state=42)

# Train Categorical Naive Bayes model
model = CategoricalNB()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification report:\n", classification_report(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.757847533632287
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       134
#            1       0.67      0.76      0.72        89
#
#     accuracy                           0.76       223
#    macro avg       0.75      0.76      0.75       223
# weighted avg       0.77      0.76      0.76       223
